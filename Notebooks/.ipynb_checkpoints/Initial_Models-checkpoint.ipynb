# %%
import sys
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from sklearn.preprocessing import PowerTransformer, FunctionTransformer, QuantileTransformer

sys.path.append('../Scripts')
from Data_Processing import DataProcessing

# %%
df = DataProcessing('../Data/train.csv')

# %%
y = df['Lap_Time']
X = df.drop(columns=['Lap_Time'])

obj_columns = X.select_dtypes(include=object).columns
num_columns = X.select_dtypes(include='number').columns

#FT = FunctionTransformer(np.log, validate=True)
#X[log_cols] = FT.fit_transform(X[log_cols])

PT = PowerTransformer(method='yeo-johnson')
X[num_columns] = PT.fit_transform(X[num_columns])

#QT = QuantileTransformer()
#X[log_cols] = QT.fit_transform(X[log_cols])
# Out:
# C:\Users\mcand\Anaconda3\lib\site-packages\numpy\core\_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# C:\Users\mcand\Anaconda3\lib\site-packages\numpy\core\_methods.py:216: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)

# %%
X[num_columns].hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000257A911AA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000257AB6C12E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000257AB6FFA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000257AB726220>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000257AB3549A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000257A9138A00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000257A9138AF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000257AB250310>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000257AB3831C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000257AB2B6940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000257AB2DD160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000257AB1EC880>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000257A91A90A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000257A95937C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025794792F40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000257947C6700>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000257947F0E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025794826640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025794850DC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000257948854C0>]],
#       dtype=object)

# %% [markdown]
# # Scalers

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import joblib

# %%
column_transformer = ColumnTransformer(
[('num', StandardScaler(), num_columns),
('obj', OneHotEncoder(), obj_columns)],
remainder='passthrough')

trans_X = column_transformer.fit_transform(X)

# %%
joblib.dump(column_transformer, '../Models/Column_Transformer.pkl')
# Out:
# ['../Models/Column_Transformer.pkl']

# %%
trans_X = trans_X.toarray()
y = np.asarray(y)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(trans_X, y, random_state=42, test_size=0.4)

# %% [markdown]
# # Neural Network

# %%
from tensorflow import keras
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras import backend as K
from keras.callbacks import EarlyStopping
from datetime import datetime

# %%
def root_mean_squared_log_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(K.log(1+y_pred) - K.log(1+y_true))))

# %%
X_train.shape
# Out:
# (6163, 81)

# %%
mc = ModelCheckpoint(f'../Models/NN_model.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=False)

model = keras.Sequential([
    keras.layers.Dense(100, activation='relu', input_dim=81),
    keras.layers.LeakyReLU(500),
    keras.layers.LeakyReLU(800),
    keras.layers.LeakyReLU(200),
    keras.layers.Dense(200, activation='relu'),
    keras.layers.Dense(1, activation='relu')
])

# %%
model.compile(optimizer='adam',
              loss=root_mean_squared_log_error,
              metrics=['mean_squared_logarithmic_error'])

# %%
history = model.fit(
    X_train,
    y_train,
    batch_size=200,
    epochs=150,
    validation_data=(X_test, y_test),
    callbacks=[mc, early_stopping]
)
# Out:
# Epoch 1/150
# 31/31 [==============================] - 1s 6ms/step - loss: 3.0387 - mean_squared_logarithmic_error: 9.6326 - val_loss: 2.0828 - val_mean_squared_logarithmic_error: 4.3386
#
# Epoch 00001: val_loss improved from inf to 2.08283, saving model to ../Models\NN_model.h5
# Epoch 2/150
# 31/31 [==============================] - 0s 3ms/step - loss: 1.5287 - mean_squared_logarithmic_error: 2.4267 - val_loss: 1.0607 - val_mean_squared_logarithmic_error: 1.1286
#
# Epoch 00002: val_loss improved from 2.08283 to 1.06071, saving model to ../Models\NN_model.h5
# Epoch 3/150
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8048 - mean_squared_logarithmic_error: 0.6698 - val_loss: 0.6187 - val_mean_squared_logarithmic_error: 0.4008
#
# Epoch 00003: val_loss improved from 1.06071 to 0.61867, saving model to ../Models\NN_model.h5
# Epoch 4/150
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5767 - mean_squared_logarithmic_error: 0.3448 - val_loss: 0.5420 - val_mean_squared_logarithmic_error: 0.3229
#
# Epoch 00004: val_loss improved from 0.61867 to 0.54199, saving model to ../Models\NN_model.h5
# Epoch 5/150
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5462 - mean_squared_logarithmic_error: 0.3195 - val_loss: 0.5372 - val_mean_squared_logarithmic_error: 0.3176
#
# Epoch 00005: val_loss improved from 0.54199 to 0.53719, saving model to ../Models\NN_model.h5
# Epoch 6/150
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5474 - mean_squared_logarithmic_error: 0.3152 - val_loss: 0.5353 - val_mean_squared_logarithmic_error: 0.3151
#
# Epoch 00006: val_loss improved from 0.53719 to 0.53530, saving model to ../Models\NN_model.h5
# Epoch 7/150
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5435 - mean_squared_logarithmic_error: 0.3119 - val_loss: 0.5339 - val_mean_squared_logarithmic_error: 0.3136
#
# Epoch 00007: val_loss improved from 0.53530 to 0.53391, saving model to ../Models\NN_model.h5
# Epoch 8/150
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5433 - mean_squared_logarithmic_error: 0.3098 - val_loss: 0.5329 - val_mean_squared_logarithmic_error: 0.3122
#
# Epoch 00008: val_loss improved from 0.53391 to 0.53293, saving model to ../Models\NN_model.h5
# Epoch 9/150
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5434 - mean_squared_logarithmic_error: 0.3078 - val_loss: 0.5327 - val_mean_squared_logarithmic_error: 0.3114
#
# Epoch 00009: val_loss improved from 0.53293 to 0.53272, saving model to ../Models\NN_model.h5
# Epoch 10/150
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5403 - mean_squared_logarithmic_error: 0.3063 - val_loss: 0.5321 - val_mean_squared_logarithmic_error: 0.3110
#
# Epoch 00010: val_loss improved from 0.53272 to 0.53208, saving model to ../Models\NN_model.h5
# Epoch 11/150
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5309 - mean_squared_logarithmic_error: 0.3055 - val_loss: 0.5314 - val_mean_squared_logarithmic_error: 0.3106
#
# Epoch 00011: val_loss improved from 0.53208 to 0.53141, saving model to ../Models\NN_model.h5
# Epoch 12/150
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5359 - mean_squared_logarithmic_error: 0.3042 - val_loss: 0.5315 - val_mean_squared_logarithmic_error: 0.3104
#
# Epoch 00012: val_loss did not improve from 0.53141
# Epoch 13/150
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5270 - mean_squared_logarithmic_error: 0.3034 - val_loss: 0.5314 - val_mean_squared_logarithmic_error: 0.3099
#
# Epoch 00013: val_loss improved from 0.53141 to 0.53141, saving model to ../Models\NN_model.h5
# Epoch 14/150
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5293 - mean_squared_logarithmic_error: 0.3024 - val_loss: 0.5316 - val_mean_squared_logarithmic_error: 0.3098
#
# Epoch 00014: val_loss did not improve from 0.53141
# Epoch 15/150
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5329 - mean_squared_logarithmic_error: 0.3020 - val_loss: 0.5313 - val_mean_squared_logarithmic_error: 0.3098
#
# Epoch 00015: val_loss improved from 0.53141 to 0.53129, saving model to ../Models\NN_model.h5
# Epoch 16/150
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5252 - mean_squared_logarithmic_error: 0.3012 - val_loss: 0.5310 - val_mean_squared_logarithmic_error: 0.3102
#
# Epoch 00016: val_loss improved from 0.53129 to 0.53098, saving model to ../Models\NN_model.h5
# Epoch 17/150
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5279 - mean_squared_logarithmic_error: 0.3007 - val_loss: 0.5312 - val_mean_squared_logarithmic_error: 0.3094
#
# Epoch 00017: val_loss did not improve from 0.53098
# Epoch 18/150
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5347 - mean_squared_logarithmic_error: 0.2996 - val_loss: 0.5314 - val_mean_squared_logarithmic_error: 0.3095
#
# Epoch 00018: val_loss did not improve from 0.53098
# Epoch 19/150
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5202 - mean_squared_logarithmic_error: 0.2988 - val_loss: 0.5310 - val_mean_squared_logarithmic_error: 0.3095
#
# Epoch 00019: val_loss did not improve from 0.53098
# Epoch 20/150
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5278 - mean_squared_logarithmic_error: 0.2988 - val_loss: 0.5310 - val_mean_squared_logarithmic_error: 0.3094
#
# Epoch 00020: val_loss did not improve from 0.53098
# Epoch 21/150
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5272 - mean_squared_logarithmic_error: 0.2983 - val_loss: 0.5310 - val_mean_squared_logarithmic_error: 0.3095
#
# Epoch 00021: val_loss did not improve from 0.53098
